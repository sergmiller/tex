# %%
import numpy as np
from scipy import stats as sps
from time import sleep
import math
import matplotlib.pyplot as plt
from scipy import interpolate

# %matplotlib inline

# %%
L = np.array([55,50,45,40,35,30,25,20,15,10,7,5,3,0])

# %%
NT = np.array([21,20,13,11,14,12,13,14,26,45,556,505,480,534])

# %%
T = np.array([98,139,101,102,102,102,103,103,102,102,37,31,30,37])

# %%
N = NT/T
pol = interpolate.lagrange(x=L[-5:],w=N[-5:])

# %%
plt.figure(figsize=(15,8))
plt.plot(L[5:], N[5:])
plt.plot(np.linspace(0,10,100), pol(np.linspace(0,10,100)))
plt.grid(True)

# %%
R_mean = 0.5*(L[-3] + L[-5])
R_extr = L[-5]

# %%
R_mean, R_extr
# Out:
# (7.5, 10)

# %%
ro = 1.2 * 1e-3

# %%
Rr_mean, Rr_extr = R_mean * ro, R_extr * ro

# %% [markdown]
# $R^{'} = \rho r \sim \frac{P}{T} r$

# %%
Rr_mean_15, Rr_extr_15 = Rr_mean * (273+20)/(273+15), Rr_extr * (273+20)/(273+15)

# %%
Rr_mean_15, Rr_extr_15
# Out:
# (0.0091562499999999995, 0.012208333333333331)

# %%
Rr_mean_15/ro, Rr_extr_15/ro
# Out:
# (7.6302083333333339, 10.173611111111111)

# %%
(273+20)/(273+15)
# Out:
# 1.0173611111111112

# %%
round(Rr_mean_15,2), round(Rr_extr_15,3), abs(Rr_extr_15 - Rr_mean_15)/Rr_mean_15
# Out:
# (0.01, 0.012, 0.3333333333333332)

# %%
N2 = np.array([100,128,159,191,230,258,307,339,367,396,
                427,464,506,540,575,620,660,710,750,790,
                860,880,920,960,990,1000,1002,1004,994,993,
                987,984,985,972,970
               ])
P = 755 - np.array([680,660,640,620,600,580,560,540,520,500,
             480,460,440,420,400,380,360,340,320,300,
             280,260,240,220,200,180,160,140,120,
             100,80,60,40,20,0
             ])

# %%
plt.figure(figsize=(15,8))
plt.plot(P,N2)
plt.plot([575,575],[0,1100])
plt.grid(True)
# plt.xlim([-100,900])

# %%
ind = 0
while N2[ind] < 1000:
    ind += 1
P0 = P[ind]

# %%
P0
# Out:
# 575

# %%
P0good = P0 * 133

# %% [markdown]
# $\rho = \frac{PM}{TR}$

# %%
ro_P0 = (P0good * 29*1e-3)/((273 + 20) * 8.3) * 1e-3

# %%
ro_P0/ro
# Out:
# 0.75995963375687059

# %%
Rr_exp = ro_P0 * 10

# %%
R_15 = 10 * (273+15)/(273+20) * P0_good/(760*133)

# %%
Rr_exp, Rr_exp/ro_P0,R_15
# Out:
# (0.0091195156050824459, 10.0, 7.4366804382971088)

# %% [markdown]
# $R = 0.32 E^{3/2}$

# %%
E = ((R_15)/0.32)**(2/3)

# %%
E
# Out:
# 8.1436561410083854

# %% [markdown]
# таблица - для энергии  6.95 МЭВ пробег в воздухе ~ 10.2 см
